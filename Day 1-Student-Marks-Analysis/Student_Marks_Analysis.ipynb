# %%
marks = [78,85,92,67,88,74,95,81,69,90]
print("Student Marks:",marks)
# Out:
# Student Marks: [78, 85, 92, 67, 88, 74, 95, 81, 69, 90]

# %%
total = sum(marks)
average = total/len(marks)
print("Total Marks:",total)
print("Average Marks:",average)
# Out:
# Total Marks: 819
# Average Marks: 81.9

# %%
highest = max(marks)
lowest = min(marks)
print("Highest Mark:",highest)
print("Lowest Mark:",lowest)
# Out:
# Highest Mark: 95
# Lowest Mark: 67

# %%
print("-----Student Marks Analysis-----")
print("Number of Students:",len(marks))
print("Total Marks:",total)
print("Average Marks:",average)
print("Highest Marks:",highest)
print("Lowest Marks:",lowest)
# Out:
# -----Student Marks Analysis-----
# Number of Students: 10
# Total Marks: 819
# Average Marks: 81.9
# Highest Marks: 95
# Lowest Marks: 67

# %% [markdown]
# # Student Marks Analysis
# ## Day 1 AI & ML Internship Task
# This project analyzes student marks using python and calculates the total, average, highest, and lowest marks

# %% [markdown]
# ## Approach
#
# 1. Store the student marks in a Python list.
# 2. Use `sum()` to calculate the total marks.
# 3. Use `len()` to find the number of students.
# 4. Calculate the average by dividing total marks by the number of students.
# 5. Use `max()` to find the highest mark.
# 6. Use `min()` to find the lowest mark.

# %% [markdown]
# ## Conclusion
#
# Python built-in functions make it easy to perform basic data processing and statistical calculations. This project demonstrates how student marks can be analyzed to find the total, average, highest, and lowest marks.
