# %%
# Employee Salary Analysis

salaries = [25000, 32000, 28000, 45000, 38000, 52000, 30000, 41000, 35000, 60000]

print("Employee Salaries:", salaries)
# Out:
# Employee Salaries: [25000, 32000, 28000, 45000, 38000, 52000, 30000, 41000, 35000, 60000]

# %%
total_salary = sum(salaries)
average_salary = total_salary / len(salaries)

print("Total Salary:", total_salary)
print("Average Salary:", average_salary)
# Out:
# Total Salary: 386000
# Average Salary: 38600.0

# %%
highest_salary = max(salaries)
lowest_salary = min(salaries)

print("Highest Salary:", highest_salary)
print("Lowest Salary:", lowest_salary)
# Out:
# Highest Salary: 60000
# Lowest Salary: 25000

# %%
print("----- Employee Salary Analysis -----")
print("Number of Employees:", len(salaries))
print("Total Salary:", total_salary)
print("Average Salary:", average_salary)
print("Highest Salary:", highest_salary)
print("Lowest Salary:", lowest_salary)
# Out:
# ----- Employee Salary Analysis -----
# Number of Employees: 10
# Total Salary: 386000
# Average Salary: 38600.0
# Highest Salary: 60000
# Lowest Salary: 25000
