# %%
# Sales Data Calculator

sales = [12000, 18500, 15000, 22000, 17500, 25000, 14000, 19500, 16000, 28000]

print("Sales Data:", sales)
# Out:
# Sales Data: [12000, 18500, 15000, 22000, 17500, 25000, 14000, 19500, 16000, 28000]

# %%
total_sales = sum(sales)
average_sales = total_sales / len(sales)

print("Total Sales:", total_sales)
print("Average Sales:", average_sales)
# Out:
# Total Sales: 187500
# Average Sales: 18750.0

# %%
highest_sale = max(sales)
lowest_sale = min(sales)

print("Highest Sale:", highest_sale)
print("Lowest Sale:", lowest_sale)
# Out:
# Highest Sale: 28000
# Lowest Sale: 12000

# %%
print("----- Sales Data Analysis -----")
print("Number of Sales Records:", len(sales))
print("Total Sales:", total_sales)
print("Average Sales:", average_sales)
print("Highest Sale:", highest_sale)
print("Lowest Sale:", lowest_sale)
# Out:
# ----- Sales Data Analysis -----
# Number of Sales Records: 10
# Total Sales: 187500
# Average Sales: 18750.0
# Highest Sale: 28000
# Lowest Sale: 12000
